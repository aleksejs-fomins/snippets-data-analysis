# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import beta, binom, gamma, cauchy

import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# %%
a, b = 2.31, 0.627
mean, var, skew, kurt = beta.stats(a, b, moments='mvsk')
np.array([mean, var, skew, kurt])
# Out:
# array([ 0.78651685,  0.04264874, -1.12407149,  0.56545748])

# %%
# %matplotlib notebook
fig, ax = plt.subplots(figsize=(2,2))

x = np.linspace(0, 1, 100)
line, = ax.plot(x, beta.pdf(x, 1, 1), 'r-')
plt.show()

@interact
def plotdist(mu=(0, 1, 0.01), k=(1, 10,0.01)):
    print(a, b)
    line.set_ydata(beta.pdf(x, mu*k, (1-mu)*k))
    ax.relim()
    ax.autoscale_view()
    fig.canvas.draw()
    fig.canvas.flush_events()
# Out:
# <img src="data:image/png;base64,..." width="199.54999999999998">
# interactive(children=(FloatSlider(value=0.0, description='mu', max=1.0, step=0.01), FloatSlider(value=5.0, des…

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize=(2,2))

x = np.linspace(0, 10, 100)
line, = ax.plot(x, cauchy.pdf(x, 0, 2), 'r-')
plt.show()
