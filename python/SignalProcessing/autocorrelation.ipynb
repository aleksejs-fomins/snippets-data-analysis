# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0, 1, 1000)
# y = np.sin(50*np.pi*x
# y = np.exp(-(x-0.5)**2 / 0.01
# y = np.random.uniform(-1, 1, 1000)
y1 = np.random.uniform(-1, 1, 1000)
y = np.array([np.sum(y1[:i]) for i in range(1000)])


plt.figure()
plt.plot(x,y)

plt.figure()
plt.plot(np.correlate(y, y, mode='full'))
